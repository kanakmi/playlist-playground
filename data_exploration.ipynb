# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('artists_datasets/language.csv')
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'year', 'popularity',
#        'artwork_url', 'album_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'track_url', 'language'],
#       dtype='str')

# %%
df[df['artist_name'].apply(lambda x: 'Taylor' in x)]
# Out:
#                      track_id  \
# 23511  1DJcbL8959LnaHt8nQc0PC
# 23512  3ePJQGn7bgRKSULeswQsfw
# 23513  2GVxYaEiKIAvJzuFvxkhWd
# 23514  1Iq8oo9XkmmvCQiGOfORiz
# 23515  5KD6AEm19QnMbfWpfoOHMl
# ...                       ...
# 24520  6zpQwkOGOTt6OCnMdNKjHl
# 24521  37enMB7tcsUq4CkibOC3Bx
# 24522  2zbVATcYiggJSWeSZkDFgd
# 44162  7p6kSsTZWbLnNXxAcwSHD1
# 56243  245uda182Ri7YysZ0gwXLL
#
#                                               track_name  \
# 23511                                Better Than Revenge
# 23512            We Are Never Ever Getting Back Together
# 23513                                          Bad Blood
# 23514  Is It Over Now? (Taylor's Version) (From The V...
# 23515  Now That We Don't Talk (Taylor's Version) (Fro...
# ...                                                  ...
# 24520                                       Shake It Off
# 24521                                        Mean - Live
# 24522                                   Out Of The Woods
# ...

# %%
df['language'].value_counts()
# Out:
# language
# English      23392
# Unknown      13005
# Tamil        12681
# Korean        6893
# Hindi         5740
# Telugu         324
# Malayalam      282
# Name: count, dtype: int64

# %%
df[df['language']=='Unknown']
# Out:
#                      track_id                                   track_name  \
# 1254   50k2lO7Z6iP3VynsspdObS                        Ori Vaari - Lofi Flip
# 1255   12l4b9Bd6wwFueqhqUxUOq       Neeye Oli - From "Sarpatta Parambarai"
# 1256   7Ci1TikgNInBn7KXyJo7a0                               Wrong Pannadha
# 1257   5DezAsjtSLUxW9j00eh0Ia       Maamadura - From "Jigarthanda DoubleX"
# 1258   7xnSWKXH8XVc8vML9132SZ                                 Unakku Thaan
# ...                       ...                                          ...
# 37253  0dqrmwx0IP64GTfzsqDoqE                       Aao Na (From "Haider")
# 37254  0DW9QbHNX4wxVxfQBuGWCS                                    Knock Out
# 37255  6CJtkFpOyax0BzJ2GqNYME  Lalla Lalla Lori (From "Welcome 2 Karachi")
# 37256  6wmztHc1PouTRZU0eroPo4                     Sooraj Se Pehele Jagaane
# 37266  0Em0Q4edL2kcWrlhmkaOzR               Besharam Rang (From "Pathaan")
#
# ...

# %%
df[df['artist_name'].apply(lambda x: 'Aujla' in x)]
# Out:
#                      track_id                     track_name  \
# 47897  1WaqQIJ0iENGWZ1QmYvYNK  Tauba Tauba (From "Bad Newz")
# 47898  3FqtduiaqnFYvBgKuc6QWQ                 Winning Speech
# 47899  5ouREJYZCYqwF0p7VeUtfH                        IDK HOW
# 47900  7KmCQLSSde0UX5OqCgvGN9                       ANTIDOTE
# 47901  209QxKVJzh2FLUmZHpYs4m                       God Damn
# ...                       ...                            ...
# 48199  4cU9Pl66UTn7w1Ba733SDZ                 Yaar Graribaaz
# 48200  5WFRB3x7ktiPb1UX08Sntw                     Little Bit
# 48201  5J8pMpCnFlFPh6v482Ejfk                 Yaar Graribaaz
# 48202  3PCXgwaCFmWRgSHxlrnSiQ                       Tru Talk
# 48203  4kTU1XirKE9UdvEi8S3VkZ                  Don't Tell Me
#
#                                              artist_name  year  popularity  \
# 47897                                        Karan Aujla  2024          71
# 47898                                 Karan Aujla, Mxrci  2024          77
# ...

# %%
df1 = pd.read_csv('songs_base_dataset.csv')
df1.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df1['artists'] = df1['artists'].astype(str)

# %%
df1[df1['artists'].apply(lambda x: 'Taylor' in str(x))]
# Out:
#         Unnamed: 0                track_id  \
# 725            725  6QYEoTGa0Boucy6htF83tb
# 774            774  3kYLpeRglpJLQkCsbp7p4j
# 852            852  5MZYOtR8fcaZoWzweBNdMm
# 1445          1445  3Wgg2Se9D2QL9I3oR8GUy8
# 1795          1795  6cLtKtakegCY6n7iepcLYJ
# ...            ...                     ...
# 103606      103606  2e9GdZASfQ1PE5qgqdJxty
# 107936      107936  1r6cqbmfVlAZYrrJMhBk7K
# 109148      109148  7EkEG47RFRjxbpSafL0Ufp
# 110249      110249  7EkEG47RFRjxbpSafL0Ufp
# 110309      110309  10EpXLXKHmNSVKvX7A5hg8
#
#                                                   artists  \
# 725     Melvin Taylor;Lucky Peterson;Titus Williams;Ra...
# 774     Melvin Taylor;Lucky Peterson;Titus Williams;Ra...
# 852                            Brandon Chase;Taylor Manns
# 1445                                           Ebo Taylor
# 1795                               Ebo Taylor;Uhuru-Yenzu
# ...                                                   ...
# ...
